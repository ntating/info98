# %%
import pandas as pd
import numpy as np
import seaborn as sn 
import sklearn.linear_model as lm
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import tensorflow as tf

# %% [markdown]
# Above we have imported the necessary libraries above. Below, we have imported a cleaned csv file from https://archive.ics.uci.edu/ml/datasets/Wine+Quality (quick cleaning for easier use done on RStudio).

# %%
red = pd.read_csv("red-wine.csv")[["fixed.acidity","volatile.acidity","citric.acid","residual.sugar",
                                   "chlorides","free.sulfur.dioxide","total.sulfur.dioxide","density",
                                   "pH","sulphates","alcohol","quality"]]
white = pd.read_csv("white-wine.csv")[["fixed.acidity","volatile.acidity","citric.acid","residual.sugar",
                                       "chlorides","free.sulfur.dioxide","total.sulfur.dioxide","density",
                                       "pH","sulphates","alcohol","quality"]]

# %%
red.head()
# Out:
#    fixed.acidity  volatile.acidity  citric.acid  residual.sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free.sulfur.dioxide  total.sulfur.dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
white.head()
# Out:
#    fixed.acidity  volatile.acidity  citric.acid  residual.sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free.sulfur.dioxide  total.sulfur.dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %% [markdown]
# Now we create the components for our linear regression model and make the quality column the y, and the rest of the table the X matrix. We both this for both the red and white wines. Then we split the data and make our predictor model.

# %%
# Create data matrix and target label 
y_red = red['quality']
X_red = red.drop(['quality'], axis=1)

y_white = white['quality']
X_white = white.drop(['quality'], axis=1)

X_red_train, X_red_test, y_red_train, y_red_test = sk.model_selection.train_test_split(X_red, y_red, train_size = .7)
predictor = lm.LinearRegression(normalize=True)
predictor.fit(X_red_train, y_red_train)
# Out:
# /Users/nick/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=True)

# %% [markdown]
# Below is the calculated mean squared error.

# %%
mse = mean_squared_error(y_red_train, predictor.predict(X_red_train))
print ('Mean squared error of the red wine training set: %s' % mse)

mse = mean_squared_error(y_red_test, predictor.predict(X_red_test))
print ('Mean squared error of the red wine test set: %s' % mse)
# Out:
# Mean squared error of the red wine training set: 0.409992985966
# Mean squared error of the red wine test set: 0.437182789399

# %% [markdown]
# How good is this predictor? What do these numbers mean? Let's see the output of our predicted labels vs. the true labels for red wine quality on our test set!

# %%
def output_labels(X, y_true): 
    y_pred = predictor.predict(X_red_test)
    y_true = y_true.values
    for i in range(y_true.shape[0]): 
        print ('Predicted Wine Quality: {}'.format(y_pred[i]))
        print ('Actual Wine Quality: {}\n\n'.format(y_true[i]))
        
output_labels(X_red_test, y_red_test)
# Out:
# Predicted Wine Quality: 5.683850526323916
# Actual Wine Quality: 4
#
#
# Predicted Wine Quality: 5.231350223920309
# Actual Wine Quality: 6
#
#
# Predicted Wine Quality: 5.717784458985005
# Actual Wine Quality: 6
#
#
# Predicted Wine Quality: 5.7376973392483315
# Actual Wine Quality: 6
#
#
# Predicted Wine Quality: 5.109578187323663
# Actual Wine Quality: 6
#
#
# Predicted Wine Quality: 6.09631761912285
# Actual Wine Quality: 7
#
#
# Predicted Wine Quality: 4.993026381508425
# Actual Wine Quality: 5
#
#
# Predicted Wine Quality: 5.6997145905366615
# Actual Wine Quality: 5
#
#
# Predicted Wine Quality: 5.367673144122936
# Actual Wine Quality: 5
#
#
# Predicted Wine Quality: 5.665705743185331
# Actual Wine Quality: 3
#
#
# Predicted Wine Quality: 6.546599108872414
# Actual Wine Quality: 6
#
#
# Predicted Wine Quality: 6.254906299371438
# Actual Wine Quality: 7
#
#
# Predicted Wine Quality: 4.92364016075533
# Actual Wine Quality: 4
#
#
# Predicted Wine Quality: 5.37005726843589
# ...

# %% [markdown]
# It seems that most of our error might be due to rounding. Let's round out our predictions and measure our new error!

# %%
mse_rounded = mean_squared_error(y_red_train, np.round(predictor.predict(X_red_train)))
print ('Mean squared error of the rounded red wine training set: %s' % mse_rounded)

mse_rounded = mean_squared_error(y_red_test, np.round(predictor.predict(X_red_test)))
print ('Mean squared error of the rounded red wine test set: %s' % mse_rounded)
# Out:
# Mean squared error of the rounded red wine training set: 0.498659517426
# Mean squared error of the rounded red wine test set: 0.529166666667

# %% [markdown]
# Lol jk, turns out that rounding makes the mse worse!

# %% [markdown]
# Now we look at the data for white wines. First we split the data into training and test.

# %%
X_white_train, X_white_test, y_white_train, y_white_test = sk.model_selection.train_test_split(X_white, y_white, train_size = .7)
predictor.fit(X_white_train, y_white_train)
# Out:
# /Users/nick/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=True)

# %%
mse = mean_squared_error(y_white_train, predictor.predict(X_white_train))
print ('Mean squared error of the white wine training set: %s' % mse)

mse = mean_squared_error(y_white_test, predictor.predict(X_white_test))
print ('Mean squared error of the white wine test set: %s' % mse)
# Out:
# Mean squared error of the white wine training set: 0.555926304936
# Mean squared error of the white wine test set: 0.585371405288

# %%
mse_rounded = mean_squared_error(y_white_train, np.round(predictor.predict(X_white_train)))
print ('Mean squared error of the rounded white wine training set: %s' % mse_rounded)

mse_rounded = mean_squared_error(y_white_test, np.round(predictor.predict(X_white_test)))
print ('Mean squared error of the rounded white wine test set: %s' % mse_rounded)
# Out:
# Mean squared error of the rounded white wine training set: 0.64585764294
# Mean squared error of the rounded white wine test set: 0.653741496599

# %% [markdown]
# According to the numbers, our predictions for red wines is better than white wines using linear regression. Now we try logistic regression!

# %%
predictor = lm.LogisticRegression()
predictor.fit(X_red_train, y_red_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
mse = mean_squared_error(y_red_train, predictor.predict(X_red_train))
print ('Mean squared error of the red wine training set: %s' % mse)

mse = mean_squared_error(y_red_test, predictor.predict(X_red_test))
print ('Mean squared error of the red wine test set: %s' % mse)
# Out:
# Mean squared error of the red wine training set: 0.518319928508
# Mean squared error of the red wine test set: 0.5375

# %%
output_labels(X_red_test, y_red_test)
# Out:
# Predicted Wine Quality: 5
# Actual Wine Quality: 4
#
#
# Predicted Wine Quality: 5
# Actual Wine Quality: 6
#
#
# Predicted Wine Quality: 6
# Actual Wine Quality: 6
#
#
# Predicted Wine Quality: 5
# Actual Wine Quality: 6
#
#
# Predicted Wine Quality: 5
# Actual Wine Quality: 6
#
#
# Predicted Wine Quality: 6
# Actual Wine Quality: 7
#
#
# Predicted Wine Quality: 5
# Actual Wine Quality: 5
#
#
# Predicted Wine Quality: 6
# Actual Wine Quality: 5
#
#
# Predicted Wine Quality: 5
# Actual Wine Quality: 5
#
#
# Predicted Wine Quality: 6
# Actual Wine Quality: 3
#
#
# Predicted Wine Quality: 7
# Actual Wine Quality: 6
#
#
# Predicted Wine Quality: 6
# Actual Wine Quality: 7
#
#
# Predicted Wine Quality: 5
# Actual Wine Quality: 4
#
#
# Predicted Wine Quality: 5
# Actual Wine Quality: 4
#
#
# Predicted Wine Quality: 5
# Actual Wine Quality: 4
#
#
# Predicted Wine Quality: 5
# Actual Wine Quality: 5
#
#
# Predicted Wine Quality: 6
# Actual Wine Quality: 6
#
#
# Predicted Wine Quality: 5
# ...

# %%
predictor.fit(X_white_train, y_white_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
mse = mean_squared_error(y_white_train, predictor.predict(X_white_train))
print ('Mean squared error of the white wine training set: %s' % mse)

mse = mean_squared_error(y_white_test, predictor.predict(X_white_test))
print ('Mean squared error of the white wine test set: %s' % mse)
# Out:
# Mean squared error of the white wine training set: 0.651400233372
# Mean squared error of the white wine test set: 0.686394557823

# %% [markdown]
# Clearly, the linear regression model is a better bit than the logistic regression model.
